# %%
import matplotlib.pyplot as plt
from random import randint
img_name = randint(0, 19000)
img = plt.imread("C:\\Users\\User\\Age-Detection-Problem\\Dataset\\Train\\Train\\" + str(img_name) + ".JPG")
plt.imshow(img)
